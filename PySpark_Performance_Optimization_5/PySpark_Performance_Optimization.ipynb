# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName("Perf_Opt").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/01 12:16:26 WARN Utils: Your hostname, bhuvaneshwaran-Latitude-5420, resolves to a loopback address: 127.0.1.1; using 192.168.1.17 instead (on interface wlp0s20f3)
# 26/01/01 12:16:26 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/01 12:16:27 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.17:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Perf_Opt</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df=spark.read.parquet(r"/home/bhuvaneshwaran/Desktop/Medium/parquetFiles/Employees.parquet")
df.show(3)
# Out:
# +---+------------+---------------+--------------------+--------------------+-----------------+-----+----------+------+--------------------+-------+--------------------+------------------+--------------------+----------+-------------+
# | id|        name|      full_name|             address|         json_string|dob_string_format|score|department|salary|        hobbies_list|user_id|            txn_date|         txn_value|              street|      city|        state|
# +---+------------+---------------+--------------------+--------------------+-----------------+-----+----------+------+--------------------+-------+--------------------+------------------+--------------------+----------+-------------+
# |  1|Advik Halder|     Janya Bala|H.No. 916, Choksh...|{"city": "Bengalu...|       1974-10-29|   74|     Sales| 95186|       [Photography]|      2|2025-11-29 13:20:...|132.71083639903748|   20/662\nDua Nagar|Coimbatore|    Rajasthan|
# |  2| Omaja Baria|   Manya Bhakta|492, Dass Road, B...|{"city": "Coimbat...|       1978-04-26|   33|   Finance| 54210|[Gaming, Cooking,...|      3|2025-11-28 13:20:...|   829.31653998402|H.No. 913, Chande...| Bengaluru|Uttar Pradesh|
# |  3|Unni Iyengar|Timothy Chaudry|H.No. 511\nJain G...|{"city": "Mumbai"...|       1999-07-25|   47|        HR|113058|            [Coding]|      4|2025-12-06 13:20:...| 913.7253175783072|922, Krishnan Circle|Coimbatore|Uttar Pradesh|
# +---+------------+---------------+--------------------+--------------------+-----------------+-----+----------+------+--------------------+-------+--------------------+------------------+--------------------+----------+-------------+
# only showing top 3 rows

# %% [markdown]
# ## 🔥 1. Partitions — The Most Important Performance Concept
# ❓ What is a partition?
#
# A partition is a chunk of data processed by one task.
#
#     * More partitions → more parallelism
#
#     * Fewer partitions → less parallelism
#
# Think like this:
#
#     One partition = one worker doing one task

# %% [markdown]
# ## 🔍 Check number of partitions

# %%
df.rdd.getNumPartitions()
# Out:
# 1

# %% [markdown]
# Explanation:
#
# df.rdd → converts DataFrame to underlying RDD
#
# getNumPartitions() → returns number of partitions

# %% [markdown]
# ❓ Why partitions matter?
#
# If:
#
#     * Partitions are too few → CPUs sit idle
#
#     * Partitions are too many → overhead increases

# %% [markdown]
# ## 🔥 Default behavior (Important)
#
#     * Reading CSV → usually 1 partition
#
#     * Reading Parquet → partitioned automatically
#
#     * spark.sql.shuffle.partitions default = 200
#
# This default is often wrong for local machines.

# %% [markdown]
# ## 🔥 2. Repartition vs Coalesce (VERY COMMON CONFUSION)
# 🔹 repartition()

# %%
df2 = df.repartition(10)

# %% [markdown]
# What it does:
#
#     * Increases or decreases partitions
#
#     * Causes a shuffle
#
#     * Redistributes data evenly
#
# When to use:
#
#     * After heavy filtering
#
#     * Before joins
#
#     * When data is skewed
#
# 🔹 coalesce()

# %%
df2 = df.coalesce(2)

# %% [markdown]
# What it does:
#
#     * Only reduces partitions
#
#     * Avoids shuffle
#
#     * Faster than repartition
#
# When to use:
#
#     * Before writing output
#
#     * When reducing file count

# %% [markdown]
# | Method      | Shuffle | Can Increase Partitions | Speed  |
# | ----------- | ------- | ----------------------- | ------ |
# | repartition | ✅ Yes   | ✅ Yes                   | Slower |
# | coalesce    | ❌ No    | ❌ No                    | Faster |

# %% [markdown]
# ## 🔥 3. Shuffles — The Biggest Performance Killer
# ❓ What is a shuffle?
#
# A shuffle happens when Spark needs to move data across partitions.
#
# This happens during:
#
#     * groupBy
#
#     * join
#
#     * distinct
#
#     * orderBy
#
#     * repartition

# %% [markdown]
# ## 🔍 Example that causes shuffle

# %%
df.columns
# Out:
# ['id',
#  'name',
#  'full_name',
#  'address',
#  'json_string',
#  'dob_string_format',
#  'score',
#  'department',
#  'salary',
#  'hobbies_list',
#  'user_id',
#  'txn_date',
#  'txn_value',
#  'street',
#  'city',
#  'state']

# %%
df.groupBy("department").count()
# Out:
# DataFrame[department: string, count: bigint]

# %% [markdown]
# Spark must:
#
#     * Move all same departments together
#
#     * This requires network transfer
#
#     * Disk + memory + CPU → expensive

# %% [markdown]
# ❗ Why shuffles are slow?
#
#     * Network IO
#
#     * Disk spill
#
#     * Serialization cost
#
#     * Memory pressure

# %% [markdown]
# 🧠 How to reduce shuffle impact?
#
#     * Filter early
#
#     * Reduce columns before groupBy
#
#     * Use broadcast joins
#
#     * Reduce spark.sql.shuffle.partitions

# %% [markdown]
# ## 🔥 4. Broadcast Joins — Huge Performance Boost
# ❓ When joining large + small tables

# %%
dim_df=df.select("id","salary")

# %%
from pyspark.sql.functions import when
dim_df=dim_df.withColumn("Sal_Cat",when(dim_df.salary>80000 , "Good").
                 when(dim_df.salary>50000,"Medium").
                 otherwise( "Low")).select("id","Sal_Cat")

# %%
dim_df.show()
# Out:
# +---+-------+
# | id|Sal_Cat|
# +---+-------+
# |  1|   Good|
# |  2| Medium|
# |  3|   Good|
# |  4|   Good|
# |  5| Medium|
# |  6|   Good|
# |  7|    Low|
# |  8|   Good|
# |  9|   Good|
# | 10|    Low|
# | 11| Medium|
# | 12|   Good|
# | 13|   Good|
# | 14| Medium|
# | 15|   Good|
# | 16|   Good|
# | 17|   Good|
# | 18|   Good|
# | 19|   Good|
# | 20|   Good|
# +---+-------+
# only showing top 20 rows

# %%
df.columns
# Out:
# ['id',
#  'name',
#  'full_name',
#  'address',
#  'json_string',
#  'dob_string_format',
#  'score',
#  'department',
#  'salary',
#  'hobbies_list',
#  'user_id',
#  'txn_date',
#  'txn_value',
#  'street',
#  'city',
#  'state']

# %%
from pyspark.sql.functions import broadcast

df_new=df.join(broadcast(dim_df), "id")
df_new.columns
# Out:
# ['id',
#  'name',
#  'full_name',
#  'address',
#  'json_string',
#  'dob_string_format',
#  'score',
#  'department',
#  'salary',
#  'hobbies_list',
#  'user_id',
#  'txn_date',
#  'txn_value',
#  'street',
#  'city',
#  'state',
#  'Sal_Cat']

# %% [markdown]
# Explanation of broadcast()
#
#     * Tells Spark: “This table is small”
#
#     * Spark sends it to all executors
#
#     * Avoids shuffle of large table
#
# When to use:
#
#     * Lookup tables
#
#     * Dimension tables
#
#     * Reference data
#
# When NOT to use:
#
#     * If table is large
#
#     * If memory is limited
#
# ## 🔥 5. Caching & Persistence (Use Carefully)
# 🔹 cache()

# %%
df.cache()
# Out:
# DataFrame[id: bigint, name: string, full_name: string, address: string, json_string: string, dob_string_format: string, score: bigint, department: string, salary: bigint, hobbies_list: array<string>, user_id: bigint, txn_date: timestamp_ntz, txn_value: double, street: string, city: string, state: string]

# %%
df_new.cache()
# Out:
# DataFrame[id: bigint, name: string, full_name: string, address: string, json_string: string, dob_string_format: string, score: bigint, department: string, salary: bigint, hobbies_list: array<string>, user_id: bigint, txn_date: timestamp_ntz, txn_value: double, street: string, city: string, state: string, Sal_Cat: string]

# %%
df.count()
# Out:
# 20000

# %% [markdown]
# Explanation:
#
#     * Stores DataFrame in memory
#
#     * Only happens after an action
#
#     * Speeds up repeated usage
#
# 🔹 persist()

# %%
df.persist()
# Out:
# 26/01/01 12:16:35 WARN CacheManager: Asked to cache already cached data.
# DataFrame[id: bigint, name: string, full_name: string, address: string, json_string: string, dob_string_format: string, score: bigint, department: string, salary: bigint, hobbies_list: array<string>, user_id: bigint, txn_date: timestamp_ntz, txn_value: double, street: string, city: string, state: string]

# %% [markdown]
# Allows different storage levels (memory + disk).
#
# ❗ Common mistake:
#
# Caching everything ❌
# Caching unused data ❌
#
# When to cache:
#
#     * Same DataFrame used multiple times
#
#     * After expensive transformations
#
# ## 🔥 6. collect() — The Silent Killer

# %%
df.collect()
# Out:
# [Row(id=1, name='Advik Halder', full_name='Janya Bala', address='H.No. 916, Chokshi Road, Mumbai, Himachal Pradesh, 383408', json_string='{"city": "Bengaluru", "zipcode": "724094", "is_capital": false}', dob_string_format='1974-10-29', score=74, department='Sales', salary=95186, hobbies_list=['Photography'], user_id=2, txn_date=datetime.datetime(2025, 11, 29, 13, 20, 36, 61574), txn_value=132.71083639903748, street='20/662\nDua Nagar', city='Coimbatore', state='Rajasthan'),
#  Row(id=2, name='Omaja Baria', full_name='Manya Bhakta', address='492, Dass Road, Bengaluru, Mizoram, 103082', json_string='{"city": "Coimbatore", "zipcode": "494894", "is_capital": true}', dob_string_format='1978-04-26', score=33, department='Finance', salary=54210, hobbies_list=['Gaming', 'Cooking', 'Photography', 'Reading'], user_id=3, txn_date=datetime.datetime(2025, 11, 28, 13, 20, 36, 61679), txn_value=829.31653998402, street='H.No. 913, Chander Path', city='Bengaluru', state='Uttar Pradesh'),
#  Row(id=3, name='Unni Iyengar', full_name='Timothy Chaudry', address='H.No. 511\nJain Ganj, Coimbatore, Jharkhand, 040655', json_string='{"city": "Mumbai", "zipcode": "334596", "is_capital": false}', dob_string_format='1999-07-25', score=47, department='HR', salary=113058, hobbies_list=['Coding'], user_id=4, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 61785), txn_value=913.7253175783072, street='922, Krishnan Circle', city='Coimbatore', state='Uttar Pradesh'),
#  Row(id=4, name='Manthan Kulkarni', full_name='Thomas Ramakrishnan', address='47\nMammen, Coimbatore, Bihar, 152655', json_string='{"city": "Salem", "zipcode": "041029", "is_capital": true}', dob_string_format='1981-08-02', score=70, department='Engineering', salary=149570, hobbies_list=['Gaming', 'Music', 'Reading'], user_id=5, txn_date=datetime.datetime(2025, 11, 29, 13, 20, 36, 61881), txn_value=566.9216358462841, street='48/18\nBir Zila', city='Mumbai', state='Nagaland'),
#  Row(id=5, name='Ayaan Rege', full_name='Hiral Rajagopalan', address='95/81\nApte Marg, Mumbai, Meghalaya, 752051', json_string='{"city": "Coimbatore", "zipcode": "393996", "is_capital": true}', dob_string_format='1962-07-13', score=80, department='Engineering', salary=78937, hobbies_list=['Music'], user_id=6, txn_date=datetime.datetime(2025, 12, 4, 13, 20, 36, 61961), txn_value=271.9908394269114, street='21\nLanka Ganj', city='Coimbatore', state='Mizoram'),
#  Row(id=6, name='Aarush Sanghvi', full_name='Nitara Misra', address='05\nBawa Street, Chennai, Nagaland, 005744', json_string='{"city": "Mumbai", "zipcode": "995656", "is_capital": false}', dob_string_format='1975-05-04', score=71, department='Sales', salary=145117, hobbies_list=['Sports', 'Farming', 'Gaming'], user_id=7, txn_date=datetime.datetime(2025, 12, 15, 13, 20, 36, 62037), txn_value=500.23970115839415, street='H.No. 79\nSachar Path', city='Mumbai', state='Himachal Pradesh'),
#  Row(id=7, name='Tristan Sahota', full_name='Abdul Agate', address='H.No. 349\nNori Marg, Mumbai, Bihar, 678621', json_string='{"city": "Bengaluru", "zipcode": "607197", "is_capital": false}', dob_string_format='1989-01-22', score=33, department='Sales', salary=34016, hobbies_list=['Photography', 'Sports', 'Farming'], user_id=8, txn_date=datetime.datetime(2025, 11, 25, 13, 20, 36, 62109), txn_value=540.363762364439, street='58\nMall Circle', city='Salem', state='Assam'),
#  Row(id=8, name='Ikshita Radhakrishnan', full_name='Mason Dugar', address='H.No. 54\nPai Chowk, Coimbatore, Manipur, 808613', json_string='{"city": "Mumbai", "zipcode": "512139", "is_capital": true}', dob_string_format='1964-05-01', score=63, department='Finance', salary=136837, hobbies_list=['Photography', 'Music'], user_id=9, txn_date=datetime.datetime(2025, 12, 19, 13, 20, 36, 62187), txn_value=814.9417332484913, street='H.No. 76\nBawa', city='Mumbai', state='Uttarakhand'),
#  Row(id=9, name='Upadhriti Tata', full_name='Upadhriti Prabhakar', address='60/534, Swamy Path, Bengaluru, Punjab, 621238', json_string='{"city": "Chennai", "zipcode": "122272", "is_capital": true}', dob_string_format='2007-11-06', score=90, department='Finance', salary=123045, hobbies_list=['Gaming', 'Cooking', 'Coding', 'Farming'], user_id=10, txn_date=datetime.datetime(2025, 12, 16, 13, 20, 36, 62261), txn_value=87.03625781156568, street='H.No. 939\nVig Ganj', city='Salem', state='Arunachal Pradesh'),
#  Row(id=10, name='Arya Sharma', full_name='Nitesh Mukhopadhyay', address='03\nDubey Ganj, Mumbai, Gujarat, 888836', json_string='{"city": "Chennai", "zipcode": "559663", "is_capital": false}', dob_string_format='1973-02-28', score=73, department='Engineering', salary=36329, hobbies_list=['Trekking', 'Cooking', 'Sports', 'Gaming'], user_id=11, txn_date=datetime.datetime(2025, 12, 18, 13, 20, 36, 62338), txn_value=72.5659838971842, street='42/20, Pandey Ganj', city='Mumbai', state='Jharkhand'),
#  Row(id=11, name='Omya Verma', full_name='Charvi Dave', address='H.No. 85\nTiwari Path, Bengaluru, Tripura, 401088', json_string='{"city": "Coimbatore", "zipcode": "036996", "is_capital": true}', dob_string_format='1962-01-13', score=68, department='Engineering', salary=76844, hobbies_list=['Sports', 'Cooking', 'Trekking'], user_id=12, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 62410), txn_value=281.7206309434518, street='120\nLuthra', city='Mumbai', state='Manipur'),
#  Row(id=12, name='Tejas Kanda', full_name='Aashi Kadakia', address='90/51\nPillai, Bengaluru, Manipur, 184056', json_string='{"city": "Coimbatore", "zipcode": "754531", "is_capital": true}', dob_string_format='1963-01-01', score=43, department='Marketing', salary=121007, hobbies_list=['Gaming'], user_id=13, txn_date=datetime.datetime(2025, 12, 3, 13, 20, 36, 62483), txn_value=230.00589320909074, street='72, Tiwari Path', city='Chennai', state='Haryana'),
#  Row(id=13, name='Jairaj Walla', full_name='Anthony Panchal', address='954\nZacharia Marg, Salem, Jharkhand, 219836', json_string='{"city": "Chennai", "zipcode": "831143", "is_capital": false}', dob_string_format='2006-03-21', score=33, department='Finance', salary=114744, hobbies_list=['Music', 'Farming', 'Photography'], user_id=14, txn_date=datetime.datetime(2025, 12, 3, 13, 20, 36, 62553), txn_value=537.9100470797238, street='734, Salvi Road', city='Salem', state='Gujarat'),
#  Row(id=14, name='Jeet Chaudry', full_name='Vivaan Anand', address='H.No. 203\nPatla Street, Chennai, Kerala, 228091', json_string='{"city": "Chennai", "zipcode": "061300", "is_capital": false}', dob_string_format='1983-09-12', score=50, department='Marketing', salary=76061, hobbies_list=['Trekking'], user_id=15, txn_date=datetime.datetime(2025, 12, 10, 13, 20, 36, 62623), txn_value=849.8031811335358, street='96, Basu', city='Coimbatore', state='Andhra Pradesh'),
#  Row(id=15, name='Arunima Uppal', full_name='Shivani Tailor', address='55/43, Pandey Ganj, Coimbatore, Gujarat, 498618', json_string='{"city": "Coimbatore", "zipcode": "639831", "is_capital": false}', dob_string_format='1981-04-20', score=82, department='Marketing', salary=100911, hobbies_list=['Farming', 'Gaming', 'Trekking'], user_id=16, txn_date=datetime.datetime(2025, 12, 14, 13, 20, 36, 62694), txn_value=968.1346253002006, street='H.No. 66\nShenoy', city='Bengaluru', state='Kerala'),
#  Row(id=16, name='Upadhriti Sachar', full_name='Nathan Loke', address='886, Chandra, Salem, Tamil Nadu, 627474', json_string='{"city": "Mumbai", "zipcode": "980755", "is_capital": false}', dob_string_format='2005-08-12', score=92, department='HR', salary=99075, hobbies_list=['Farming', 'Photography'], user_id=17, txn_date=datetime.datetime(2025, 12, 3, 13, 20, 36, 62764), txn_value=937.095377190446, street='86, Muni Chowk', city='Salem', state='Uttar Pradesh'),
#  Row(id=17, name='Bhanumati Sethi', full_name='Wazir Gera', address='172\nSolanki Nagar, Bengaluru, Odisha, 357193', json_string='{"city": "Salem", "zipcode": "346144", "is_capital": true}', dob_string_format='1994-08-18', score=80, department='Marketing', salary=119373, hobbies_list=['Farming'], user_id=18, txn_date=datetime.datetime(2025, 12, 2, 13, 20, 36, 62844), txn_value=570.476390311164, street='79/01\nChopra Marg', city='Bengaluru', state='Tripura'),
#  Row(id=18, name='Darsh Chada', full_name='Zaitra Handa', address='492\nMukhopadhyay Circle, Chennai, Tripura, 506061', json_string='{"city": "Coimbatore", "zipcode": "438812", "is_capital": true}', dob_string_format='1993-11-05', score=75, department='Sales', salary=126499, hobbies_list=['Cooking', 'Coding', 'Farming', 'Sports'], user_id=19, txn_date=datetime.datetime(2025, 12, 13, 13, 20, 36, 62922), txn_value=310.36500086880557, street='90, Pau Chowk', city='Coimbatore', state='Karnataka'),
#  Row(id=19, name='Rishi Bail', full_name='Tristan Iyer', address='659\nSodhi Zila, Coimbatore, Andhra Pradesh, 319286', json_string='{"city": "Chennai", "zipcode": "469240", "is_capital": true}', dob_string_format='2007-10-02', score=64, department='Finance', salary=105467, hobbies_list=['Coding', 'Gaming'], user_id=20, txn_date=datetime.datetime(2025, 12, 19, 13, 20, 36, 62997), txn_value=80.59658796100761, street='H.No. 28, Mandal Road', city='Coimbatore', state='Tripura'),
#  Row(id=20, name='Madhavi Ghose', full_name='Samesh Bains', address='28/73\nBoase Chowk, Salem, Haryana, 663289', json_string='{"city": "Chennai", "zipcode": "254687", "is_capital": true}', dob_string_format='2002-02-17', score=70, department='HR', salary=117193, hobbies_list=['Photography', 'Reading'], user_id=21, txn_date=datetime.datetime(2025, 12, 23, 13, 20, 36, 63065), txn_value=557.3296074747828, street='H.No. 92, Bir Chowk', city='Coimbatore', state='West Bengal'),
#  Row(id=21, name='Owen Ramaswamy', full_name='Aditya Boase', address='39/250, Kuruvilla Ganj, Bengaluru, Karnataka, 438393', json_string='{"city": "Mumbai", "zipcode": "055754", "is_capital": false}', dob_string_format='1991-09-23', score=95, department='Sales', salary=74949, hobbies_list=['Reading', 'Cooking', 'Trekking', 'Gaming'], user_id=22, txn_date=datetime.datetime(2025, 12, 15, 13, 20, 36, 63137), txn_value=876.4962710206212, street='H.No. 830\nKala', city='Chennai', state='Sikkim'),
#  Row(id=22, name='Watika Banik', full_name='Siddharth Natt', address='11/127\nPatil, Chennai, Nagaland, 059950', json_string='{"city": "Salem", "zipcode": "924298", "is_capital": true}', dob_string_format='1964-01-18', score=75, department='Sales', salary=64731, hobbies_list=['Music', 'Photography', 'Cooking'], user_id=23, txn_date=datetime.datetime(2025, 12, 24, 13, 20, 36, 63209), txn_value=124.5124853689214, street='H.No. 42\nChanda Zila', city='Mumbai', state='Arunachal Pradesh'),
#  Row(id=23, name='Jagrati Lala', full_name='Devika Puri', address='805\nLata Marg, Bengaluru, Arunachal Pradesh, 243594', json_string='{"city": "Coimbatore", "zipcode": "935455", "is_capital": false}', dob_string_format='2004-12-02', score=33, department='Marketing', salary=122879, hobbies_list=['Music', 'Gaming'], user_id=24, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 63278), txn_value=421.1743417434226, street='61\nBrahmbhatt Chowk', city='Coimbatore', state='Odisha'),
#  Row(id=24, name='Upasna Pillay', full_name='Zansi Deol', address='68/479, Iyengar, Bengaluru, Assam, 717205', json_string='{"city": "Coimbatore", "zipcode": "287774", "is_capital": true}', dob_string_format='1994-10-10', score=62, department='Engineering', salary=126031, hobbies_list=['Gaming', 'Cooking', 'Music'], user_id=25, txn_date=datetime.datetime(2025, 12, 7, 13, 20, 36, 63348), txn_value=16.641613819195843, street='881, Chaudhary Nagar', city='Bengaluru', state='Telangana'),
#  Row(id=25, name='Adweta Shere', full_name='Nidhi Sharma', address='40, Chand Chowk, Mumbai, West Bengal, 674595', json_string='{"city": "Chennai", "zipcode": "386915", "is_capital": false}', dob_string_format='1986-11-29', score=37, department='Engineering', salary=80570, hobbies_list=['Sports'], user_id=26, txn_date=datetime.datetime(2025, 12, 4, 13, 20, 36, 63415), txn_value=88.8907441053156, street='H.No. 09\nSoman Circle', city='Mumbai', state='Kerala'),
#  Row(id=26, name='Tanveer Sem', full_name='Yashvi Sundaram', address='21/40\nBatta Street, Coimbatore, Assam, 418935', json_string='{"city": "Coimbatore", "zipcode": "713117", "is_capital": false}', dob_string_format='1976-02-03', score=88, department='Engineering', salary=138665, hobbies_list=['Farming'], user_id=27, txn_date=datetime.datetime(2025, 11, 27, 13, 20, 36, 63484), txn_value=80.3315419749552, street='H.No. 722, Pant Zila', city='Salem', state='Assam'),
#  Row(id=27, name='Jacob Bali', full_name='Nimrat Batra', address='H.No. 51\nPeri Path, Mumbai, Himachal Pradesh, 770625', json_string='{"city": "Salem", "zipcode": "876274", "is_capital": true}', dob_string_format='1995-04-17', score=40, department='Sales', salary=98005, hobbies_list=['Cooking', 'Reading', 'Sports'], user_id=28, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 63552), txn_value=951.3806634478854, street='81, Halder Road', city='Mumbai', state='Uttar Pradesh'),
#  Row(id=28, name='Jeet Kale', full_name='Jack Samra', address='02, Mani Street, Mumbai, Goa, 255428', json_string='{"city": "Coimbatore", "zipcode": "471550", "is_capital": true}', dob_string_format='1999-05-03', score=93, department='Engineering', salary=134523, hobbies_list=['Gaming', 'Cooking', 'Sports'], user_id=29, txn_date=datetime.datetime(2025, 12, 3, 13, 20, 36, 63624), txn_value=700.1848279068126, street='48/89\nNarula Ganj', city='Salem', state='Himachal Pradesh'),
#  Row(id=29, name='Vrinda Rana', full_name='Ryan Dada', address='03/99, Kadakia Chowk, Coimbatore, Chhattisgarh, 292233', json_string='{"city": "Coimbatore", "zipcode": "876466", "is_capital": true}', dob_string_format='1993-05-28', score=54, department='Engineering', salary=87510, hobbies_list=['Trekking'], user_id=30, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 63695), txn_value=382.7884368003513, street='H.No. 549\nChhabra Ganj', city='Mumbai', state='Chhattisgarh'),
#  Row(id=30, name='Darpan Divan', full_name='Watika Dara', address='H.No. 380, Kapur Marg, Coimbatore, Goa, 262653', json_string='{"city": "Mumbai", "zipcode": "577136", "is_capital": false}', dob_string_format='1979-04-23', score=47, department='Finance', salary=45894, hobbies_list=['Photography', 'Coding', 'Farming', 'Gaming'], user_id=31, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 63769), txn_value=34.898226919549955, street='H.No. 10, Lalla Chowk', city='Mumbai', state='Chhattisgarh'),
#  Row(id=31, name='Maya Oommen', full_name='Advik Pillay', address='67/628\nChad Marg, Coimbatore, Mizoram, 380292', json_string='{"city": "Mumbai", "zipcode": "928238", "is_capital": false}', dob_string_format='1970-04-30', score=58, department='Sales', salary=130980, hobbies_list=['Sports'], user_id=32, txn_date=datetime.datetime(2025, 12, 3, 13, 20, 36, 63850), txn_value=153.79378463162448, street='82/590, Dora Street', city='Chennai', state='Assam'),
#  Row(id=32, name='Hritik Naik', full_name='Zehaan Varkey', address='H.No. 69\nParekh, Bengaluru, Odisha, 116975', json_string='{"city": "Mumbai", "zipcode": "191479", "is_capital": false}', dob_string_format='2003-09-07', score=93, department='Finance', salary=90867, hobbies_list=['Reading'], user_id=33, txn_date=datetime.datetime(2025, 11, 27, 13, 20, 36, 63918), txn_value=292.3051454481581, street='H.No. 81\nNagar Ganj', city='Coimbatore', state='Andhra Pradesh'),
#  Row(id=33, name='Triveni Dey', full_name='Mitali Sunder', address='684\nKeer Chowk, Chennai, Uttarakhand, 144118', json_string='{"city": "Salem", "zipcode": "614252", "is_capital": false}', dob_string_format='1997-05-04', score=45, department='HR', salary=88257, hobbies_list=['Photography', 'Music', 'Cooking'], user_id=34, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 63989), txn_value=945.9801886385533, street='99/478\nMallick Street', city='Salem', state='Bihar'),
#  Row(id=34, name='Ucchal Jani', full_name='Chaaya Gulati', address='92/665, Dada Marg, Salem, Nagaland, 984119', json_string='{"city": "Coimbatore", "zipcode": "094353", "is_capital": true}', dob_string_format='1966-02-21', score=81, department='HR', salary=85014, hobbies_list=['Music'], user_id=35, txn_date=datetime.datetime(2025, 12, 8, 13, 20, 36, 64061), txn_value=416.7408913161887, street='H.No. 92\nGulati Nagar', city='Coimbatore', state='Gujarat'),
#  Row(id=35, name='Orinder Gala', full_name='Warda Ramaswamy', address='H.No. 41, Lad Marg, Mumbai, Meghalaya, 549754', json_string='{"city": "Bengaluru", "zipcode": "680010", "is_capital": false}', dob_string_format='1984-11-01', score=38, department='Marketing', salary=49557, hobbies_list=['Sports', 'Cooking'], user_id=36, txn_date=datetime.datetime(2025, 12, 8, 13, 20, 36, 64130), txn_value=157.26808030867693, street='H.No. 676, Edwin Circle', city='Bengaluru', state='Gujarat'),
#  Row(id=36, name='Viraj Sur', full_name='Lipika Vasa', address='035\nSharaf, Mumbai, Uttar Pradesh, 734917', json_string='{"city": "Mumbai", "zipcode": "380677", "is_capital": false}', dob_string_format='1989-03-26', score=80, department='HR', salary=85045, hobbies_list=['Cooking', 'Photography', 'Farming', 'Sports'], user_id=37, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 64198), txn_value=704.0192068042746, street='H.No. 37, Krishnamurthy', city='Salem', state='Telangana'),
#  Row(id=37, name='Oviya Dube', full_name='Upkaar Bose', address='H.No. 489\nDe Chowk, Salem, Haryana, 115507', json_string='{"city": "Mumbai", "zipcode": "329428", "is_capital": true}', dob_string_format='1999-09-13', score=32, department='HR', salary=137053, hobbies_list=['Sports', 'Farming', 'Trekking'], user_id=38, txn_date=datetime.datetime(2025, 12, 24, 13, 20, 36, 64268), txn_value=431.6849078919613, street='82/506\nDevan Path', city='Mumbai', state='Madhya Pradesh'),
#  Row(id=38, name='Ekanta Wali', full_name='Teerth Vohra', address='H.No. 79, Patla Path, Coimbatore, Jharkhand, 071166', json_string='{"city": "Bengaluru", "zipcode": "177359", "is_capital": true}', dob_string_format='1984-09-06', score=68, department='Finance', salary=122533, hobbies_list=['Gaming', 'Trekking'], user_id=39, txn_date=datetime.datetime(2025, 11, 29, 13, 20, 36, 64336), txn_value=486.8509445811945, street='73\nBalan Street', city='Bengaluru', state='Madhya Pradesh'),
#  Row(id=39, name='Nisha Rajagopal', full_name='Faraj Pillai', address='10/95, Handa Nagar, Salem, Assam, 074556', json_string='{"city": "Chennai", "zipcode": "698215", "is_capital": false}', dob_string_format='1976-08-31', score=67, department='Sales', salary=36352, hobbies_list=['Music'], user_id=40, txn_date=datetime.datetime(2025, 11, 25, 13, 20, 36, 64414), txn_value=589.4899148285357, street='H.No. 82\nBose Street', city='Salem', state='Manipur'),
#  Row(id=40, name='Abha Chaudhary', full_name='Bachittar Bahri', address='25/469\nSodhi Zila, Coimbatore, Andhra Pradesh, 433111', json_string='{"city": "Mumbai", "zipcode": "176128", "is_capital": true}', dob_string_format='1991-05-21', score=78, department='Sales', salary=144082, hobbies_list=['Sports'], user_id=41, txn_date=datetime.datetime(2025, 12, 20, 13, 20, 36, 64486), txn_value=611.6909897459789, street='H.No. 832, Sunder Nagar', city='Chennai', state='Tamil Nadu'),
#  Row(id=41, name='Xavier Yadav', full_name='Ethan Nagi', address='83/802, Mallick Path, Chennai, Rajasthan, 416867', json_string='{"city": "Bengaluru", "zipcode": "493430", "is_capital": false}', dob_string_format='1992-03-19', score=40, department='Finance', salary=32599, hobbies_list=['Trekking', 'Cooking', 'Music', 'Coding'], user_id=42, txn_date=datetime.datetime(2025, 12, 3, 13, 20, 36, 64556), txn_value=763.4788942562122, street='H.No. 927\nSarna', city='Bengaluru', state='Rajasthan'),
#  Row(id=42, name='Anamika Bora', full_name='Nilima Mammen', address='96/791, Sule Path, Chennai, Himachal Pradesh, 163954', json_string='{"city": "Mumbai", "zipcode": "834073", "is_capital": false}', dob_string_format='2000-03-08', score=35, department='Engineering', salary=53831, hobbies_list=['Music', 'Reading', 'Trekking', 'Sports'], user_id=43, txn_date=datetime.datetime(2025, 12, 21, 13, 20, 36, 64626), txn_value=360.8084030091024, street='H.No. 036, Mann Street', city='Bengaluru', state='Sikkim'),
#  Row(id=43, name='Aryan Loke', full_name='Hitesh Choudhry', address='16/206\nChakrabarti Marg, Chennai, Gujarat, 274379', json_string='{"city": "Coimbatore", "zipcode": "948450", "is_capital": false}', dob_string_format='1976-08-27', score=85, department='Finance', salary=32895, hobbies_list=['Music', 'Cooking'], user_id=44, txn_date=datetime.datetime(2025, 11, 25, 13, 20, 36, 64697), txn_value=40.43921437592683, street='00/54, Sekhon Street', city='Chennai', state='Kerala'),
#  Row(id=44, name='Gautami Bal', full_name='Girish Balan', address='95, Ratti Ganj, Coimbatore, Jharkhand, 582887', json_string='{"city": "Mumbai", "zipcode": "997220", "is_capital": true}', dob_string_format='1974-12-23', score=33, department='Marketing', salary=52245, hobbies_list=['Farming', 'Gaming', 'Music'], user_id=45, txn_date=datetime.datetime(2025, 12, 14, 13, 20, 36, 64764), txn_value=610.4413971855638, street='596\nPatil Zila', city='Mumbai', state='Goa'),
#  Row(id=45, name='Aarini Ray', full_name='Ira Mand', address='H.No. 095, Tak Ganj, Chennai, West Bengal, 104521', json_string='{"city": "Bengaluru", "zipcode": "119330", "is_capital": false}', dob_string_format='1981-06-29', score=31, department='Marketing', salary=123869, hobbies_list=['Sports', 'Cooking', 'Reading'], user_id=46, txn_date=datetime.datetime(2025, 12, 5, 13, 20, 36, 64838), txn_value=486.9916950219777, street='H.No. 683\nKala Ganj', city='Bengaluru', state='Uttarakhand'),
#  Row(id=46, name='Agastya Mitra', full_name='Champak Saini', address='59/81, Kalita Street, Coimbatore, Mizoram, 821545', json_string='{"city": "Bengaluru", "zipcode": "693248", "is_capital": true}', dob_string_format='1992-01-27', score=86, department='Engineering', salary=93064, hobbies_list=['Coding', 'Farming', 'Gaming', 'Cooking'], user_id=47, txn_date=datetime.datetime(2025, 12, 10, 13, 20, 36, 64913), txn_value=522.3736237426762, street='615, Saxena Zila', city='Mumbai', state='Uttar Pradesh'),
#  Row(id=47, name='Lipika Datta', full_name='Bhavani Bora', address='38/08, Setty Circle, Salem, Meghalaya, 972409', json_string='{"city": "Bengaluru", "zipcode": "788120", "is_capital": false}', dob_string_format='2006-02-20', score=37, department='HR', salary=102933, hobbies_list=['Farming'], user_id=48, txn_date=datetime.datetime(2025, 11, 26, 13, 20, 36, 64985), txn_value=832.6468960571912, street='184\nParsa Path', city='Salem', state='Himachal Pradesh'),
#  Row(id=48, name='Yatan Sidhu', full_name='Chavvi Din', address='45/18, Rastogi Marg, Bengaluru, Uttar Pradesh, 234291', json_string='{"city": "Chennai", "zipcode": "924881", "is_capital": true}', dob_string_format='1990-01-14', score=50, department='Finance', salary=94298, hobbies_list=['Photography'], user_id=49, txn_date=datetime.datetime(2025, 12, 5, 13, 20, 36, 65053), txn_value=409.6190866362184, street='H.No. 18\nWable Marg', city='Salem', state='Assam'),
#  Row(id=49, name='Megha Tailor', full_name='Irya Goswami', address='12/924\nHari Ganj, Bengaluru, Himachal Pradesh, 728134', json_string='{"city": "Chennai", "zipcode": "405686", "is_capital": true}', dob_string_format='1974-01-04', score=75, department='Engineering', salary=130088, hobbies_list=['Photography'], user_id=50, txn_date=datetime.datetime(2025, 12, 17, 13, 20, 36, 65122), txn_value=14.969571335506973, street='47/022, Venkataraman Zila', city='Bengaluru', state='Madhya Pradesh'),
#  Row(id=50, name='Jacob Koshy', full_name='Indrajit Rao', address='H.No. 83\nChar Circle, Mumbai, Manipur, 370113', json_string='{"city": "Salem", "zipcode": "109789", "is_capital": true}', dob_string_format='1993-09-23', score=31, department='Marketing', salary=43034, hobbies_list=['Farming', 'Photography', 'Gaming'], user_id=51, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 65190), txn_value=113.5216678887541, street='H.No. 124, Patla Street', city='Coimbatore', state='Sikkim'),
#  Row(id=51, name='Unni Chhabra', full_name='Chaitaly Nagy', address='10/082, Sastry Circle, Salem, Assam, 814316', json_string='{"city": "Mumbai", "zipcode": "977749", "is_capital": true}', dob_string_format='1987-04-09', score=99, department='Marketing', salary=86083, hobbies_list=['Photography', 'Sports'], user_id=52, txn_date=datetime.datetime(2025, 12, 2, 13, 20, 36, 65261), txn_value=745.3509319490166, street='H.No. 54, Raja Circle', city='Salem', state='Madhya Pradesh'),
#  Row(id=52, name='Chanchal Pall', full_name='Samuel Dara', address='522\nDin Street, Salem, Mizoram, 922298', json_string='{"city": "Salem", "zipcode": "952453", "is_capital": true}', dob_string_format='2002-09-20', score=49, department='Marketing', salary=35624, hobbies_list=['Photography', 'Coding'], user_id=53, txn_date=datetime.datetime(2025, 12, 19, 13, 20, 36, 65331), txn_value=270.9232849335674, street='40, Sharma Path', city='Coimbatore', state='Goa'),
#  Row(id=53, name='Ayushman Mand', full_name='Alka Talwar', address='776\nRam Road, Bengaluru, Meghalaya, 921233', json_string='{"city": "Salem", "zipcode": "021259", "is_capital": true}', dob_string_format='1998-07-19', score=43, department='Marketing', salary=126782, hobbies_list=['Coding', 'Sports'], user_id=54, txn_date=datetime.datetime(2025, 12, 11, 13, 20, 36, 65403), txn_value=133.362728934046, street='25\nSane Path', city='Bengaluru', state='Maharashtra'),
#  Row(id=54, name='Finn Talwar', full_name='Oni Butala', address='H.No. 55\nSehgal Street, Mumbai, Andhra Pradesh, 193329', json_string='{"city": "Salem", "zipcode": "112575", "is_capital": false}', dob_string_format='1985-07-07', score=53, department='Marketing', salary=93641, hobbies_list=['Coding'], user_id=55, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 65472), txn_value=11.21917820773613, street='875\nKeer Circle', city='Bengaluru', state='Sikkim'),
#  Row(id=55, name='Thomas Sem', full_name='Chandani Basu', address='53\nMalhotra Zila, Coimbatore, Arunachal Pradesh, 333933', json_string='{"city": "Salem", "zipcode": "149311", "is_capital": false}', dob_string_format='1978-05-12', score=89, department='Engineering', salary=123726, hobbies_list=['Reading', 'Trekking', 'Photography'], user_id=56, txn_date=datetime.datetime(2025, 12, 5, 13, 20, 36, 65555), txn_value=766.5697125045346, street='681\nBarman', city='Mumbai', state='Haryana'),
#  Row(id=56, name='Vamakshi Kannan', full_name='Yug Chaudhary', address='70/30, Tara Ganj, Mumbai, Nagaland, 520281', json_string='{"city": "Salem", "zipcode": "228962", "is_capital": false}', dob_string_format='1974-02-22', score=82, department='Engineering', salary=96392, hobbies_list=['Gaming', 'Photography', 'Farming', 'Sports'], user_id=57, txn_date=datetime.datetime(2025, 12, 15, 13, 20, 36, 65623), txn_value=43.0172113365815, street='78\nMody Chowk', city='Mumbai', state='Gujarat'),
#  Row(id=57, name='Gunbir Wable', full_name='Aahana Balakrishnan', address='00\nKhanna Chowk, Chennai, Punjab, 429301', json_string='{"city": "Salem", "zipcode": "841989", "is_capital": true}', dob_string_format='1989-10-18', score=92, department='Finance', salary=88191, hobbies_list=['Sports', 'Gaming', 'Photography', 'Trekking'], user_id=58, txn_date=datetime.datetime(2025, 12, 18, 13, 20, 36, 65694), txn_value=159.6498468319241, street='663, Dave Chowk', city='Bengaluru', state='Meghalaya'),
#  Row(id=58, name='David Narain', full_name='Mohammed Bali', address='H.No. 47, Pai Circle, Coimbatore, Assam, 315095', json_string='{"city": "Coimbatore", "zipcode": "932186", "is_capital": false}', dob_string_format='1967-01-15', score=67, department='Marketing', salary=84108, hobbies_list=['Photography', 'Farming', 'Gaming'], user_id=59, txn_date=datetime.datetime(2025, 11, 25, 13, 20, 36, 65761), txn_value=332.70184686559713, street='H.No. 40, Pal Zila', city='Mumbai', state='Uttar Pradesh'),
#  Row(id=59, name='Anay Naidu', full_name='Daksha Jain', address='H.No. 665\nHari Ganj, Bengaluru, Kerala, 991317', json_string='{"city": "Mumbai", "zipcode": "865926", "is_capital": false}', dob_string_format='1965-03-26', score=94, department='Marketing', salary=108960, hobbies_list=['Cooking'], user_id=60, txn_date=datetime.datetime(2025, 11, 29, 13, 20, 36, 65833), txn_value=153.47403874128395, street='358\nPuri Road', city='Salem', state='Sikkim'),
#  Row(id=60, name='Banjeet Krishna', full_name='Benjamin Goel', address='66/48, Loke Marg, Salem, Andhra Pradesh, 868389', json_string='{"city": "Mumbai", "zipcode": "260925", "is_capital": false}', dob_string_format='1963-03-07', score=81, department='Marketing', salary=45537, hobbies_list=['Gaming'], user_id=61, txn_date=datetime.datetime(2025, 12, 19, 13, 20, 36, 65911), txn_value=509.26780383169165, street='39\nNatt Nagar', city='Salem', state='Tripura'),
#  Row(id=61, name='Daksha Deol', full_name='Om Warrior', address='61/18\nBakshi Marg, Mumbai, Madhya Pradesh, 011906', json_string='{"city": "Coimbatore", "zipcode": "369431", "is_capital": false}', dob_string_format='1984-06-27', score=50, department='HR', salary=139595, hobbies_list=['Sports'], user_id=62, txn_date=datetime.datetime(2025, 12, 13, 13, 20, 36, 66017), txn_value=22.819442471284898, street='58/443\nBaral', city='Salem', state='Mizoram'),
#  Row(id=62, name='Ishaan Shankar', full_name='Bhanumati Date', address='H.No. 138\nDey, Coimbatore, Maharashtra, 884957', json_string='{"city": "Chennai", "zipcode": "373278", "is_capital": false}', dob_string_format='1978-08-16', score=30, department='Marketing', salary=113205, hobbies_list=['Gaming', 'Music', 'Sports'], user_id=63, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 66127), txn_value=778.6280879140888, street='355, Singhal Path', city='Mumbai', state='West Bengal'),
#  Row(id=63, name='Hritik Sarma', full_name='Bhavna Sampath', address='26/071, More Chowk, Salem, Arunachal Pradesh, 376387', json_string='{"city": "Coimbatore", "zipcode": "543018", "is_capital": false}', dob_string_format='1992-06-25', score=87, department='HR', salary=38806, hobbies_list=['Gaming', 'Sports', 'Farming', 'Trekking'], user_id=64, txn_date=datetime.datetime(2025, 11, 25, 13, 20, 36, 66237), txn_value=707.0658935131419, street='64\nRaj Path', city='Mumbai', state='Manipur'),
#  Row(id=64, name='Gayathri Mukherjee', full_name='Tripti Chandra', address='93\nChana Zila, Bengaluru, Sikkim, 001607', json_string='{"city": "Bengaluru", "zipcode": "915589", "is_capital": false}', dob_string_format='1993-11-22', score=53, department='HR', salary=120883, hobbies_list=['Coding', 'Farming'], user_id=65, txn_date=datetime.datetime(2025, 12, 17, 13, 20, 36, 66354), txn_value=657.039973794146, street='05/021, Gokhale Ganj', city='Chennai', state='Telangana'),
#  Row(id=65, name='Ekavir Puri', full_name='Aarini Dua', address='27/818\nSodhi, Coimbatore, Madhya Pradesh, 841087', json_string='{"city": "Mumbai", "zipcode": "440915", "is_capital": true}', dob_string_format='1993-03-26', score=45, department='Engineering', salary=147576, hobbies_list=['Trekking', 'Farming', 'Sports'], user_id=66, txn_date=datetime.datetime(2025, 11, 30, 13, 20, 36, 66688), txn_value=199.8859177508042, street='72/65\nMurty Path', city='Salem', state='Nagaland'),
#  Row(id=66, name='Nakul Sampath', full_name='Bimala Iyer', address='08/47, Pillai Street, Chennai, Mizoram, 578935', json_string='{"city": "Salem", "zipcode": "496937", "is_capital": true}', dob_string_format='1982-03-28', score=67, department='Engineering', salary=71485, hobbies_list=['Cooking'], user_id=67, txn_date=datetime.datetime(2025, 12, 7, 13, 20, 36, 66813), txn_value=838.9538251675143, street='358, Boase Nagar', city='Bengaluru', state='Rajasthan'),
#  Row(id=67, name='Damini Loyal', full_name='Saumya Sekhon', address='42/977, Chakraborty Road, Salem, Gujarat, 563671', json_string='{"city": "Mumbai", "zipcode": "975021", "is_capital": true}', dob_string_format='1965-05-28', score=88, department='HR', salary=148866, hobbies_list=['Farming'], user_id=68, txn_date=datetime.datetime(2025, 11, 26, 13, 20, 36, 66917), txn_value=869.0355375965636, street='H.No. 46, Buch', city='Mumbai', state='Himachal Pradesh'),
#  Row(id=68, name='Ijaya Bhagat', full_name='Tristan Bera', address='H.No. 247, Sarin Zila, Mumbai, Uttar Pradesh, 351264', json_string='{"city": "Coimbatore", "zipcode": "446881", "is_capital": false}', dob_string_format='1981-07-13', score=78, department='Engineering', salary=74223, hobbies_list=['Music', 'Reading'], user_id=69, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 67026), txn_value=154.0658886431417, street='18/864, Tata Marg', city='Chennai', state='Karnataka'),
#  Row(id=69, name='Alexander Kade', full_name='Manthan Chopra', address='H.No. 89, Kothari Path, Bengaluru, Meghalaya, 011183', json_string='{"city": "Chennai", "zipcode": "066512", "is_capital": true}', dob_string_format='1999-09-30', score=93, department='Engineering', salary=105706, hobbies_list=['Photography', 'Gaming'], user_id=70, txn_date=datetime.datetime(2025, 12, 12, 13, 20, 36, 67140), txn_value=728.9379470347653, street='80/98\nSethi Circle', city='Bengaluru', state='Chhattisgarh'),
#  Row(id=70, name='Arin Johal', full_name='Zaitra Ravi', address='H.No. 677, Raval Ganj, Mumbai, Gujarat, 779745', json_string='{"city": "Bengaluru", "zipcode": "410510", "is_capital": true}', dob_string_format='1992-02-22', score=97, department='Engineering', salary=62173, hobbies_list=['Farming', 'Cooking'], user_id=71, txn_date=datetime.datetime(2025, 12, 2, 13, 20, 36, 67250), txn_value=880.7283871285362, street='H.No. 05\nRavel Ganj', city='Salem', state='Haryana'),
#  Row(id=71, name='Aahana Hora', full_name='Sanya Bajaj', address='63/53, Lata Chowk, Salem, Andhra Pradesh, 414066', json_string='{"city": "Coimbatore", "zipcode": "063842", "is_capital": false}', dob_string_format='1999-05-15', score=80, department='HR', salary=65282, hobbies_list=['Farming', 'Gaming', 'Music', 'Sports'], user_id=72, txn_date=datetime.datetime(2025, 11, 27, 13, 20, 36, 67365), txn_value=224.63866165443008, street='H.No. 872\nChaudry Road', city='Salem', state='Gujarat'),
#  Row(id=72, name='Ishanvi Hora', full_name='Ikbal Bhandari', address='22\nPalla Chowk, Mumbai, Andhra Pradesh, 288864', json_string='{"city": "Bengaluru", "zipcode": "212632", "is_capital": true}', dob_string_format='2005-07-18', score=53, department='Marketing', salary=113014, hobbies_list=['Music', 'Trekking', 'Gaming', 'Photography'], user_id=73, txn_date=datetime.datetime(2025, 12, 22, 13, 20, 36, 67481), txn_value=316.5009815781798, street='368\nKoshy Street', city='Coimbatore', state='Tamil Nadu'),
#  Row(id=73, name='Luke Bal', full_name='Nitara Patil', address='H.No. 865\nBandi Circle, Salem, Karnataka, 895251', json_string='{"city": "Bengaluru", "zipcode": "337623", "is_capital": false}', dob_string_format='1993-04-26', score=89, department='Sales', salary=146356, hobbies_list=['Reading'], user_id=74, txn_date=datetime.datetime(2025, 12, 8, 13, 20, 36, 67584), txn_value=45.399828155653566, street='334, Bora', city='Coimbatore', state='Nagaland'),
#  Row(id=74, name='Fitan Bal', full_name='Isaiah Deol', address='H.No. 048, Nagarajan Street, Chennai, Himachal Pradesh, 824740', json_string='{"city": "Bengaluru", "zipcode": "746416", "is_capital": false}', dob_string_format='1977-06-03', score=69, department='Sales', salary=84614, hobbies_list=['Reading'], user_id=75, txn_date=datetime.datetime(2025, 11, 28, 13, 20, 36, 67696), txn_value=343.0408810823349, street='H.No. 871\nDesai Road', city='Mumbai', state='Meghalaya'),
#  Row(id=75, name='Siya Biswas', full_name='Januja Brahmbhatt', address='02\nKeer Chowk, Bengaluru, Karnataka, 358509', json_string='{"city": "Mumbai", "zipcode": "676709", "is_capital": true}', dob_string_format='1982-05-06', score=69, department='Engineering', salary=59178, hobbies_list=['Sports', 'Farming'], user_id=76, txn_date=datetime.datetime(2025, 12, 7, 13, 20, 36, 67807), txn_value=280.6426776424539, street='262\nJain Zila', city='Salem', state='Nagaland'),
#  Row(id=76, name='Chakradev Lad', full_name='Manbir Mann', address='322, Radhakrishnan Path, Mumbai, Maharashtra, 313486', json_string='{"city": "Bengaluru", "zipcode": "221068", "is_capital": true}', dob_string_format='1976-01-30', score=63, department='Marketing', salary=32176, hobbies_list=['Gaming', 'Music', 'Cooking', 'Trekking'], user_id=77, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 67904), txn_value=445.39325627666346, street='50/32\nPandit Path', city='Salem', state='Andhra Pradesh'),
#  Row(id=77, name='Damyanti Mandal', full_name='Veer Keer', address='82, Mistry Ganj, Bengaluru, Sikkim, 075899', json_string='{"city": "Bengaluru", "zipcode": "271251", "is_capital": false}', dob_string_format='1979-03-06', score=71, department='Marketing', salary=118339, hobbies_list=['Cooking', 'Trekking', 'Reading', 'Gaming'], user_id=78, txn_date=datetime.datetime(2025, 12, 1, 13, 20, 36, 67979), txn_value=888.3084645974437, street='07/73, Chaudhry Road', city='Bengaluru', state='Mizoram'),
#  Row(id=78, name='Saumya Singhal', full_name='Libni Kashyap', address='H.No. 90, Kamdar Street, Chennai, Goa, 752239', json_string='{"city": "Salem", "zipcode": "994156", "is_capital": false}', dob_string_format='1980-07-28', score=38, department='Finance', salary=114676, hobbies_list=['Trekking', 'Coding'], user_id=79, txn_date=datetime.datetime(2025, 11, 26, 13, 20, 36, 68053), txn_value=548.7674869048514, street='28/854\nAtwal Zila', city='Salem', state='Andhra Pradesh'),
#  Row(id=79, name='Arjun Raju', full_name='Vrishti Kale', address='70, Sant Path, Chennai, Manipur, 209528', json_string='{"city": "Bengaluru", "zipcode": "199759", "is_capital": true}', dob_string_format='1985-12-20', score=75, department='HR', salary=57355, hobbies_list=['Photography', 'Sports', 'Gaming', 'Coding'], user_id=80, txn_date=datetime.datetime(2025, 12, 7, 13, 20, 36, 68126), txn_value=164.79811803912136, street='H.No. 001\nMall Nagar', city='Mumbai', state='Uttarakhand'),
#  Row(id=80, name='Aashi Varghese', full_name='Samesh Warrior', address='H.No. 83\nIyer Ganj, Mumbai, Haryana, 148983', json_string='{"city": "Mumbai", "zipcode": "841874", "is_capital": true}', dob_string_format='1970-03-17', score=31, department='Finance', salary=135132, hobbies_list=['Coding'], user_id=81, txn_date=datetime.datetime(2025, 11, 25, 13, 20, 36, 68197), txn_value=800.6605250170453, street='32/734, Cherian Street', city='Mumbai', state='Arunachal Pradesh'),
#  Row(id=81, name='Mason Bandi', full_name='Hamsini Nath', address='54/58, Bains Circle, Chennai, Goa, 559052', json_string='{"city": "Salem", "zipcode": "471329", "is_capital": false}', dob_string_format='1979-04-12', score=50, department='Sales', salary=120795, hobbies_list=['Reading'], user_id=82, txn_date=datetime.datetime(2025, 12, 17, 13, 20, 36, 68264), txn_value=692.9950813501551, street='44\nRavel Road', city='Bengaluru', state='West Bengal'),
#  Row(id=82, name='Hemangini Dar', full_name='Pranav Divan', address='42\nKrish Chowk, Mumbai, Uttarakhand, 073713', json_string='{"city": "Coimbatore", "zipcode": "963454", "is_capital": true}', dob_string_format='1999-11-30', score=83, department='HR', salary=33920, hobbies_list=['Reading'], user_id=83, txn_date=datetime.datetime(2025, 12, 10, 13, 20, 36, 68335), txn_value=342.58648625311764, street='54/94, Sankaran', city='Salem', state='Tamil Nadu'),
#  Row(id=83, name='Gaurika Bhalla', full_name='Pranit Shetty', address='03/82\nRandhawa, Coimbatore, West Bengal, 141338', json_string='{"city": "Bengaluru", "zipcode": "377289", "is_capital": false}', dob_string_format='1999-02-23', score=53, department='Engineering', salary=139428, hobbies_list=['Coding', 'Cooking'], user_id=84, txn_date=datetime.datetime(2025, 12, 13, 13, 20, 36, 68405), txn_value=297.4321723259059, street='41/343\nKurian', city='Salem', state='Assam'),
#  Row(id=84, name='Arin Lad', full_name='Aarini Goswami', address='71/81, Oza Street, Chennai, Meghalaya, 872815', json_string='{"city": "Bengaluru", "zipcode": "301032", "is_capital": false}', dob_string_format='1973-02-14', score=62, department='Marketing', salary=100634, hobbies_list=['Sports', 'Trekking', 'Photography', 'Coding'], user_id=85, txn_date=datetime.datetime(2025, 12, 12, 13, 20, 36, 68475), txn_value=139.07973412241208, street='80/29, Sood Street', city='Bengaluru', state='West Bengal'),
#  Row(id=85, name='Chaaya Yadav', full_name='Reyansh Viswanathan', address='H.No. 343\nNagy Nagar, Bengaluru, Odisha, 762774', json_string='{"city": "Salem", "zipcode": "537554", "is_capital": false}', dob_string_format='1979-02-18', score=90, department='Engineering', salary=141277, hobbies_list=['Reading', 'Music', 'Photography'], user_id=86, txn_date=datetime.datetime(2025, 12, 10, 13, 20, 36, 68545), txn_value=34.171996756350275, street='H.No. 23\nOommen Road', city='Mumbai', state='Tripura'),
#  Row(id=86, name='Gaurangi Brar', full_name='Anjali Balasubramanian', address='62\nSandhu, Coimbatore, Gujarat, 375195', json_string='{"city": "Mumbai", "zipcode": "644813", "is_capital": true}', dob_string_format='1971-08-28', score=48, department='Sales', salary=134183, hobbies_list=['Gaming'], user_id=87, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 68613), txn_value=11.10282017885214, street='47/388, Bal Ganj', city='Salem', state='Maharashtra'),
#  Row(id=87, name='Timothy Mohanty', full_name='Nathaniel Minhas', address='849\nKoshy Zila, Salem, Sikkim, 247649', json_string='{"city": "Mumbai", "zipcode": "678686", "is_capital": false}', dob_string_format='1981-08-18', score=65, department='Finance', salary=134480, hobbies_list=['Reading', 'Music', 'Coding'], user_id=88, txn_date=datetime.datetime(2025, 12, 15, 13, 20, 36, 68685), txn_value=421.5169971002574, street='H.No. 587\nSarraf Chowk', city='Salem', state='Sikkim'),
#  Row(id=88, name='Bishakha Sachar', full_name='Harini Dar', address='481, Pandit Circle, Salem, Tamil Nadu, 741356', json_string='{"city": "Chennai", "zipcode": "916977", "is_capital": true}', dob_string_format='1991-02-12', score=94, department='Sales', salary=73816, hobbies_list=['Photography', 'Reading'], user_id=89, txn_date=datetime.datetime(2025, 12, 3, 13, 20, 36, 68754), txn_value=245.48212896567765, street='H.No. 94, Kapur Circle', city='Mumbai', state='Meghalaya'),
#  Row(id=89, name='Garima Shenoy', full_name='Yauvani Bajwa', address='83/042\nDixit, Bengaluru, Karnataka, 292643', json_string='{"city": "Mumbai", "zipcode": "194880", "is_capital": true}', dob_string_format='1979-09-17', score=53, department='Sales', salary=49780, hobbies_list=['Reading', 'Coding'], user_id=90, txn_date=datetime.datetime(2025, 11, 26, 13, 20, 36, 68835), txn_value=474.18817982766427, street='52/827\nComar Ganj', city='Salem', state='Rajasthan'),
#  Row(id=90, name='Jason Choudhary', full_name='Faras Rai', address='49/74, Khatri Chowk, Mumbai, Uttar Pradesh, 430534', json_string='{"city": "Chennai", "zipcode": "727090", "is_capital": true}', dob_string_format='1964-08-07', score=64, department='Sales', salary=131748, hobbies_list=['Gaming', 'Trekking', 'Cooking'], user_id=91, txn_date=datetime.datetime(2025, 12, 16, 13, 20, 36, 68907), txn_value=976.7311040692745, street='884, Parsa Road', city='Coimbatore', state='Odisha'),
#  Row(id=91, name='Leela Karpe', full_name='Laban Gola', address='H.No. 14\nDyal Chowk, Chennai, Rajasthan, 926188', json_string='{"city": "Bengaluru", "zipcode": "623605", "is_capital": true}', dob_string_format='1985-12-18', score=37, department='Marketing', salary=31272, hobbies_list=['Music'], user_id=92, txn_date=datetime.datetime(2025, 12, 11, 13, 20, 36, 68976), txn_value=680.8582659053969, street='65, Basak Street', city='Salem', state='Jharkhand'),
#  Row(id=92, name='Aadhya Gaba', full_name='Omisha Singhal', address='15, Bala Circle, Mumbai, Tripura, 649329', json_string='{"city": "Mumbai", "zipcode": "843107", "is_capital": true}', dob_string_format='1976-02-04', score=90, department='Engineering', salary=135990, hobbies_list=['Coding'], user_id=93, txn_date=datetime.datetime(2025, 12, 13, 13, 20, 36, 69046), txn_value=211.5693195134686, street='569, Panchal Marg', city='Chennai', state='Tripura'),
#  Row(id=93, name='Atharv Dalal', full_name='Eshana Jani', address='56/273\nPandey Nagar, Bengaluru, Punjab, 959799', json_string='{"city": "Coimbatore", "zipcode": "616412", "is_capital": true}', dob_string_format='1988-09-06', score=58, department='Finance', salary=89828, hobbies_list=['Farming'], user_id=94, txn_date=datetime.datetime(2025, 12, 24, 13, 20, 36, 69114), txn_value=618.0160581601974, street='H.No. 11, Vig Ganj', city='Chennai', state='Rajasthan'),
#  Row(id=94, name='Pallavi Ahuja', full_name='Waida Upadhyay', address='276\nBajaj Zila, Salem, Uttar Pradesh, 319474', json_string='{"city": "Coimbatore", "zipcode": "323891", "is_capital": false}', dob_string_format='1987-02-02', score=98, department='Marketing', salary=106636, hobbies_list=['Photography', 'Gaming'], user_id=95, txn_date=datetime.datetime(2025, 12, 20, 13, 20, 36, 69182), txn_value=410.66800233045245, street='76\nKorpal', city='Coimbatore', state='Jharkhand'),
#  Row(id=95, name='Shivansh Dutta', full_name='Joshua Bora', address='421\nBrar Path, Bengaluru, Jharkhand, 689414', json_string='{"city": "Salem", "zipcode": "575825", "is_capital": false}', dob_string_format='1992-04-16', score=62, department='Marketing', salary=41497, hobbies_list=['Music', 'Photography', 'Cooking', 'Gaming'], user_id=96, txn_date=datetime.datetime(2025, 12, 7, 13, 20, 36, 69254), txn_value=729.8258728306281, street='15/13\nPradhan Nagar', city='Mumbai', state='Punjab'),
#  Row(id=96, name='Rayaan Varkey', full_name='Riya Patla', address='38, Mann Nagar, Mumbai, Arunachal Pradesh, 143092', json_string='{"city": "Mumbai", "zipcode": "346999", "is_capital": true}', dob_string_format='1967-08-09', score=37, department='Finance', salary=61628, hobbies_list=['Reading', 'Music', 'Trekking'], user_id=97, txn_date=datetime.datetime(2025, 12, 15, 13, 20, 36, 69324), txn_value=990.3425533455243, street='59/436, Nazareth', city='Salem', state='Punjab'),
#  Row(id=97, name='Dayamai Jani', full_name='Rajeshri Kaur', address='617\nUppal Zila, Coimbatore, Haryana, 630934', json_string='{"city": "Bengaluru", "zipcode": "563619", "is_capital": true}', dob_string_format='1993-02-22', score=55, department='Finance', salary=147433, hobbies_list=['Reading', 'Music', 'Coding'], user_id=98, txn_date=datetime.datetime(2025, 12, 4, 13, 20, 36, 69392), txn_value=460.9042584029494, street='H.No. 746, Baral Chowk', city='Salem', state='Karnataka'),
#  Row(id=98, name='Dayita Sha', full_name='Jagat Brahmbhatt', address='H.No. 40\nAnne Zila, Chennai, Uttarakhand, 711608', json_string='{"city": "Mumbai", "zipcode": "420532", "is_capital": true}', dob_string_format='1967-02-02', score=48, department='HR', salary=79231, hobbies_list=['Coding', 'Photography', 'Sports', 'Reading'], user_id=99, txn_date=datetime.datetime(2025, 12, 19, 13, 20, 36, 69464), txn_value=832.7980718331763, street='03/360\nKibe', city='Bengaluru', state='Bihar'),
#  Row(id=99, name='Kiaan Thaman', full_name='Sudiksha Varughese', address='01/92, Agrawal Ganj, Bengaluru, Arunachal Pradesh, 525043', json_string='{"city": "Mumbai", "zipcode": "572727", "is_capital": true}', dob_string_format='1960-05-20', score=70, department='Finance', salary=90034, hobbies_list=['Coding', 'Music', 'Photography', 'Gaming'], user_id=100, txn_date=datetime.datetime(2025, 12, 19, 13, 20, 36, 69534), txn_value=361.0793134541523, street='H.No. 58, Ganesan Circle', city='Salem', state='Karnataka'),
# ...
#  Row(id=969, name='Garima Misra', full_name='Baghyawati Sachdev', address='05/277, Shanker, Salem, Meghalaya, 103861', json_string='{"city": "Chennai", "zipcode": "590803", "is_capital": false}', dob_string_format='1996-12-09', score=75, department='Sales', salary=133737, hobbies_list=['Gaming'], user_id=470, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 128270), txn_value=446.75593983915576, street='H.No. 99\nAtwal Ganj', city='Salem', state='Goa'),
#  Row(id=970, name='Ayaan Nagi', full_name='Janani Tandon', address='H.No. 129, Kota Marg, Mumbai, Kerala, 886981', json_string='{"city": "Chennai", "zipcode": "561850", "is_capital": true}', dob_string_format='1978-03-31', score=59, department='Finance', salary=103662, hobbies_list=['Gaming', 'Trekking', 'Cooking', 'Coding'], user_id=471, txn_date=datetime.datetime(2025, 12, 10, 13, 20, 36, 128332), txn_value=282.57093587645744, street='280, Parekh Chowk', city='Chennai', state='Maharashtra'),
#  Row(id=971, name='Hema Bhavsar', full_name='Rishi Bansal', address='771\nBhasin Marg, Salem, Uttarakhand, 829338', json_string='{"city": "Mumbai", "zipcode": "229801", "is_capital": true}', dob_string_format='1961-02-02', score=85, department='HR', salary=73289, hobbies_list=['Reading', 'Gaming', 'Farming', 'Trekking'], user_id=472, txn_date=datetime.datetime(2025, 12, 4, 13, 20, 36, 128394), txn_value=634.4796533896542, street='H.No. 192, Naidu Chowk', city='Bengaluru', state='Chhattisgarh'),
#  Row(id=972, name='Jalsa Parekh', full_name='Robert Shan', address='03/40, Barad Nagar, Salem, Himachal Pradesh, 014382', json_string='{"city": "Coimbatore", "zipcode": "932399", "is_capital": false}', dob_string_format='1985-04-08', score=62, department='Sales', salary=89678, hobbies_list=['Sports', 'Cooking', 'Music', 'Trekking'], user_id=473, txn_date=datetime.datetime(2025, 12, 5, 13, 20, 36, 128458), txn_value=64.59614820724627, street='H.No. 00, Mittal Path', city='Coimbatore', state='Haryana'),
#  Row(id=973, name='Wakeeta Morar', full_name='Lucky Apte', address='592\nCheema Circle, Coimbatore, Goa, 668582', json_string='{"city": "Bengaluru", "zipcode": "349400", "is_capital": true}', dob_string_format='1961-09-03', score=33, department='Finance', salary=89111, hobbies_list=['Cooking'], user_id=474, txn_date=datetime.datetime(2025, 12, 1, 13, 20, 36, 128523), txn_value=829.0424666735373, street='31/34\nSethi Ganj', city='Chennai', state='Karnataka'),
#  Row(id=974, name='Adweta Biswas', full_name='Chandresh Gokhale', address='62, Sura Street, Mumbai, Tripura, 986837', json_string='{"city": "Coimbatore", "zipcode": "829661", "is_capital": false}', dob_string_format='1965-02-15', score=57, department='HR', salary=47248, hobbies_list=['Reading'], user_id=475, txn_date=datetime.datetime(2025, 11, 29, 13, 20, 36, 128585), txn_value=102.71235005653737, street='89\nAhluwalia Chowk', city='Bengaluru', state='Punjab'),
#  Row(id=975, name='Aashi Mistry', full_name='Leela Reddy', address='33\nViswanathan Nagar, Salem, Haryana, 485126', json_string='{"city": "Salem", "zipcode": "834658", "is_capital": true}', dob_string_format='2002-11-18', score=51, department='Finance', salary=43482, hobbies_list=['Coding'], user_id=476, txn_date=datetime.datetime(2025, 12, 2, 13, 20, 36, 128647), txn_value=522.9310647680377, street='48/604\nMutti Nagar', city='Coimbatore', state='Arunachal Pradesh'),
#  Row(id=976, name='Jairaj Doshi', full_name='Yahvi Chaudhary', address='16/655, Khalsa Ganj, Bengaluru, Tamil Nadu, 323519', json_string='{"city": "Bengaluru", "zipcode": "720841", "is_capital": true}', dob_string_format='1962-06-18', score=42, department='Finance', salary=81328, hobbies_list=['Coding', 'Reading', 'Gaming'], user_id=477, txn_date=datetime.datetime(2025, 12, 1, 13, 20, 36, 128713), txn_value=920.1479232383265, street='H.No. 396, Sekhon Circle', city='Coimbatore', state='Odisha'),
#  Row(id=977, name='Pranit Shanker', full_name='Mekhala Walla', address='H.No. 98, Patil Zila, Coimbatore, Telangana, 956387', json_string='{"city": "Coimbatore", "zipcode": "299730", "is_capital": true}', dob_string_format='1977-03-11', score=90, department='HR', salary=123234, hobbies_list=['Sports'], user_id=478, txn_date=datetime.datetime(2025, 12, 5, 13, 20, 36, 128774), txn_value=868.3884228875513, street='51\nGour Ganj', city='Chennai', state='Haryana'),
#  Row(id=978, name='Neha Zachariah', full_name='Geetika Murthy', address='32/209\nHora Chowk, Bengaluru, Maharashtra, 832858', json_string='{"city": "Chennai", "zipcode": "128470", "is_capital": false}', dob_string_format='1993-01-22', score=71, department='Finance', salary=108906, hobbies_list=['Farming', 'Music', 'Photography', 'Cooking'], user_id=479, txn_date=datetime.datetime(2025, 12, 2, 13, 20, 36, 128844), txn_value=898.5438367441088, street='99\nMandal Chowk', city='Chennai', state='Gujarat'),
#  Row(id=979, name='Dayamai Kamdar', full_name='Veda Deshpande', address='987\nManne Street, Salem, Kerala, 741720', json_string='{"city": "Chennai", "zipcode": "196991", "is_capital": false}', dob_string_format='1982-10-06', score=30, department='HR', salary=103944, hobbies_list=['Gaming'], user_id=480, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 128915), txn_value=131.7617363696345, street='H.No. 449, Baria Road', city='Mumbai', state='Himachal Pradesh'),
#  Row(id=980, name='Patrick Saha', full_name='Upkaar Dugar', address='58/89, Karan Marg, Salem, Punjab, 261508', json_string='{"city": "Mumbai", "zipcode": "906214", "is_capital": true}', dob_string_format='1984-09-09', score=81, department='Marketing', salary=49356, hobbies_list=['Music', 'Coding', 'Photography'], user_id=481, txn_date=datetime.datetime(2025, 11, 25, 13, 20, 36, 128982), txn_value=63.35577575338182, street='H.No. 54, Behl Circle', city='Bengaluru', state='Andhra Pradesh'),
#  Row(id=981, name='Harish Arya', full_name='Diya Ramachandran', address='H.No. 015, Rastogi Road, Coimbatore, Haryana, 810252', json_string='{"city": "Salem", "zipcode": "891855", "is_capital": false}', dob_string_format='1981-05-03', score=77, department='Engineering', salary=73537, hobbies_list=['Sports', 'Photography'], user_id=482, txn_date=datetime.datetime(2025, 12, 11, 13, 20, 36, 129045), txn_value=803.9511738805817, street='H.No. 24, Tandon Path', city='Bengaluru', state='Andhra Pradesh'),
#  Row(id=982, name='Prisha Sha', full_name='Siya Varkey', address='44/69\nAhuja Path, Bengaluru, Mizoram, 848378', json_string='{"city": "Bengaluru", "zipcode": "378440", "is_capital": true}', dob_string_format='1966-12-22', score=57, department='Sales', salary=61011, hobbies_list=['Reading'], user_id=483, txn_date=datetime.datetime(2025, 11, 26, 13, 20, 36, 129110), txn_value=85.47816923629917, street='27\nChaudhuri Road', city='Salem', state='Telangana'),
#  Row(id=983, name='Parth Andra', full_name='Balveer Mane', address='454\nAgarwal Zila, Salem, Haryana, 447805', json_string='{"city": "Bengaluru", "zipcode": "817050", "is_capital": false}', dob_string_format='1979-09-24', score=34, department='Marketing', salary=100015, hobbies_list=['Reading', 'Music', 'Sports'], user_id=484, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 129180), txn_value=526.9348829612399, street='H.No. 29\nDani Marg', city='Coimbatore', state='Telangana'),
#  Row(id=984, name='Janya Karpe', full_name='Liam Ray', address='993, Kibe Marg, Mumbai, Maharashtra, 501728', json_string='{"city": "Salem", "zipcode": "928986", "is_capital": false}', dob_string_format='2002-12-25', score=76, department='Finance', salary=46038, hobbies_list=['Coding'], user_id=485, txn_date=datetime.datetime(2025, 12, 24, 13, 20, 36, 129258), txn_value=899.9459769838796, street='658\nVarkey Ganj', city='Coimbatore', state='Manipur'),
#  Row(id=985, name='Nitara Mander', full_name='Wakeeta Chadha', address='98/659, Narayan Nagar, Chennai, Sikkim, 997602', json_string='{"city": "Mumbai", "zipcode": "432411", "is_capital": false}', dob_string_format='1979-12-09', score=88, department='Sales', salary=65701, hobbies_list=['Coding', 'Cooking'], user_id=486, txn_date=datetime.datetime(2025, 12, 11, 13, 20, 36, 129332), txn_value=415.1957592206416, street='201\nArora Path', city='Chennai', state='Meghalaya'),
#  Row(id=986, name='Saanvi Raja', full_name='Ati Guha', address='H.No. 66, Sama, Bengaluru, Sikkim, 835420', json_string='{"city": "Coimbatore", "zipcode": "590405", "is_capital": false}', dob_string_format='1972-07-20', score=50, department='Finance', salary=89857, hobbies_list=['Farming', 'Photography'], user_id=487, txn_date=datetime.datetime(2025, 11, 25, 13, 20, 36, 129403), txn_value=288.75194003197134, street='155\nGara Marg', city='Coimbatore', state='Jharkhand'),
#  Row(id=987, name='Jagdish Deo', full_name='Yutika Mani', address='738\nMagar Zila, Salem, Maharashtra, 878270', json_string='{"city": "Chennai", "zipcode": "839839", "is_capital": true}', dob_string_format='1991-06-01', score=96, department='Engineering', salary=98399, hobbies_list=['Photography'], user_id=488, txn_date=datetime.datetime(2025, 12, 22, 13, 20, 36, 129474), txn_value=822.2598839523085, street='H.No. 151, Magar', city='Bengaluru', state='Bihar'),
#  Row(id=988, name='Zehaan Halder', full_name='Zinal Malhotra', address='H.No. 10\nAndra Circle, Mumbai, West Bengal, 787027', json_string='{"city": "Mumbai", "zipcode": "321460", "is_capital": false}', dob_string_format='1990-01-30', score=92, department='Sales', salary=77238, hobbies_list=['Gaming', 'Photography', 'Sports', 'Trekking'], user_id=489, txn_date=datetime.datetime(2025, 12, 12, 13, 20, 36, 129540), txn_value=410.7000676356481, street='H.No. 48\nKala Path', city='Mumbai', state='Haryana'),
#  Row(id=989, name='Kritika Ghosh', full_name='Ishwar Issac', address='402\nGoswami Zila, Salem, Jharkhand, 700821', json_string='{"city": "Salem", "zipcode": "235052", "is_capital": true}', dob_string_format='1995-09-08', score=40, department='HR', salary=38323, hobbies_list=['Cooking', 'Gaming'], user_id=490, txn_date=datetime.datetime(2025, 12, 19, 13, 20, 36, 129608), txn_value=521.1605341013499, street='89/59\nBawa Zila', city='Chennai', state='Tripura'),
#  Row(id=990, name='Maanav Sura', full_name='Ekaraj Biswas', address='50\nNagar, Coimbatore, West Bengal, 039412', json_string='{"city": "Salem", "zipcode": "425798", "is_capital": false}', dob_string_format='1995-11-19', score=80, department='Engineering', salary=50274, hobbies_list=['Sports', 'Photography', 'Cooking', 'Coding'], user_id=491, txn_date=datetime.datetime(2025, 12, 8, 13, 20, 36, 129670), txn_value=903.446801517139, street='736, Kara Road', city='Mumbai', state='Kerala'),
#  Row(id=991, name='Abhimanyu Tak', full_name='Anya Loke', address='H.No. 104\nMall Chowk, Coimbatore, Sikkim, 715777', json_string='{"city": "Chennai", "zipcode": "732005", "is_capital": true}', dob_string_format='1964-01-03', score=47, department='Marketing', salary=37366, hobbies_list=['Gaming', 'Reading', 'Cooking', 'Photography'], user_id=492, txn_date=datetime.datetime(2025, 12, 20, 13, 20, 36, 129737), txn_value=36.09910169452133, street='H.No. 07\nSahni Nagar', city='Coimbatore', state='Meghalaya'),
#  Row(id=992, name='Bhavani Deshpande', full_name='Matthew Halder', address='41/857\nMall Circle, Coimbatore, Karnataka, 724844', json_string='{"city": "Chennai", "zipcode": "361953", "is_capital": false}', dob_string_format='1997-11-19', score=59, department='Engineering', salary=127966, hobbies_list=['Farming', 'Gaming', 'Reading'], user_id=493, txn_date=datetime.datetime(2025, 11, 26, 13, 20, 36, 129809), txn_value=676.852536153728, street='58\nKant Circle', city='Coimbatore', state='Rajasthan'),
#  Row(id=993, name='Falan Sengupta', full_name='Jasmit Andra', address='78/339\nMukhopadhyay Ganj, Mumbai, Uttar Pradesh, 274081', json_string='{"city": "Chennai", "zipcode": "802432", "is_capital": true}', dob_string_format='1992-12-06', score=62, department='Marketing', salary=114165, hobbies_list=['Gaming', 'Photography', 'Reading', 'Coding'], user_id=494, txn_date=datetime.datetime(2025, 12, 12, 13, 20, 36, 129881), txn_value=100.90168964133989, street='05/46\nChaudhry Marg', city='Chennai', state='Haryana'),
#  Row(id=994, name='Ucchal Edwin', full_name='Gaurangi Virk', address='694\nWason Street, Bengaluru, Uttarakhand, 063447', json_string='{"city": "Mumbai", "zipcode": "630059", "is_capital": false}', dob_string_format='1974-04-19', score=44, department='Sales', salary=59294, hobbies_list=['Farming', 'Trekking', 'Reading', 'Sports'], user_id=495, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 129944), txn_value=89.1768333663909, street='589, Sarin Marg', city='Coimbatore', state='Kerala'),
#  Row(id=995, name='Zaitra Ghose', full_name='Benjamin Patel', address='H.No. 364\nBabu Ganj, Salem, Assam, 308676', json_string='{"city": "Mumbai", "zipcode": "891553", "is_capital": false}', dob_string_format='1974-10-23', score=94, department='Sales', salary=32566, hobbies_list=['Reading', 'Photography'], user_id=496, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 130007), txn_value=530.7626474003291, street='75/84, Dhawan Circle', city='Bengaluru', state='Jharkhand'),
#  Row(id=996, name='Zilmil Mall', full_name='Elijah Mital', address='H.No. 42, Iyengar Path, Bengaluru, Nagaland, 770187', json_string='{"city": "Mumbai", "zipcode": "887146", "is_capital": true}', dob_string_format='2004-11-19', score=31, department='Engineering', salary=138207, hobbies_list=['Sports', 'Photography', 'Reading', 'Gaming'], user_id=497, txn_date=datetime.datetime(2025, 12, 24, 13, 20, 36, 130072), txn_value=359.15583808269866, street='93/030, Baral Chowk', city='Coimbatore', state='Meghalaya'),
#  Row(id=997, name='Darpan Vora', full_name='Amruta Kapadia', address='87/92, Grover Ganj, Bengaluru, Punjab, 092899', json_string='{"city": "Bengaluru", "zipcode": "093536", "is_capital": false}', dob_string_format='1969-07-28', score=33, department='Marketing', salary=133159, hobbies_list=['Trekking', 'Reading', 'Photography', 'Music'], user_id=498, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 130135), txn_value=445.18446993566033, street='H.No. 66, Bhavsar Path', city='Bengaluru', state='Himachal Pradesh'),
#  Row(id=998, name='Raagini Chakrabarti', full_name='Ranbir Guha', address='H.No. 15\nTalwar Marg, Chennai, Mizoram, 607609', json_string='{"city": "Chennai", "zipcode": "203345", "is_capital": false}', dob_string_format='2007-10-09', score=35, department='Finance', salary=144287, hobbies_list=['Gaming'], user_id=499, txn_date=datetime.datetime(2025, 12, 15, 13, 20, 36, 130197), txn_value=580.7013332747626, street='H.No. 81\nShankar Chowk', city='Mumbai', state='Meghalaya'),
#  Row(id=999, name='Balvan Bir', full_name='Peter Swamy', address='H.No. 885\nKannan Circle, Chennai, Uttarakhand, 532046', json_string='{"city": "Mumbai", "zipcode": "239499", "is_capital": false}', dob_string_format='1973-09-30', score=30, department='Sales', salary=114128, hobbies_list=['Cooking', 'Farming'], user_id=500, txn_date=datetime.datetime(2025, 12, 10, 13, 20, 36, 130260), txn_value=907.1310654058552, street='733, Mammen', city='Bengaluru', state='Arunachal Pradesh'),
#  Row(id=1000, name='Naveen Chandran', full_name='Naveen Prabhu', address='08/627\nRege, Bengaluru, Sikkim, 947770', json_string='{"city": "Bengaluru", "zipcode": "900479", "is_capital": true}', dob_string_format='1981-04-01', score=73, department='Engineering', salary=30404, hobbies_list=['Trekking', 'Music'], user_id=1, txn_date=datetime.datetime(2025, 12, 9, 13, 20, 36, 130324), txn_value=922.6794924166948, street='32/173\nPai', city='Chennai', state='Tamil Nadu'),
#  ...]

# %% [markdown]
# What it does:
#
#     * Brings ALL data to driver memory
#
# Why dangerous:
#
#     * Driver OOM crash
#
#     * Works on small data, fails in production
#
# Safe alternatives:

# %%
df.show(3)
# Out:
# +---+------------+---------------+--------------------+--------------------+-----------------+-----+----------+------+--------------------+-------+--------------------+------------------+--------------------+----------+-------------+
# | id|        name|      full_name|             address|         json_string|dob_string_format|score|department|salary|        hobbies_list|user_id|            txn_date|         txn_value|              street|      city|        state|
# +---+------------+---------------+--------------------+--------------------+-----------------+-----+----------+------+--------------------+-------+--------------------+------------------+--------------------+----------+-------------+
# |  1|Advik Halder|     Janya Bala|H.No. 916, Choksh...|{"city": "Bengalu...|       1974-10-29|   74|     Sales| 95186|       [Photography]|      2|2025-11-29 13:20:...|132.71083639903748|   20/662\nDua Nagar|Coimbatore|    Rajasthan|
# |  2| Omaja Baria|   Manya Bhakta|492, Dass Road, B...|{"city": "Coimbat...|       1978-04-26|   33|   Finance| 54210|[Gaming, Cooking,...|      3|2025-11-28 13:20:...|   829.31653998402|H.No. 913, Chande...| Bengaluru|Uttar Pradesh|
# |  3|Unni Iyengar|Timothy Chaudry|H.No. 511\nJain G...|{"city": "Mumbai"...|       1999-07-25|   47|        HR|113058|            [Coding]|      4|2025-12-06 13:20:...| 913.7253175783072|922, Krishnan Circle|Coimbatore|Uttar Pradesh|
# +---+------------+---------------+--------------------+--------------------+-----------------+-----+----------+------+--------------------+-------+--------------------+------------------+--------------------+----------+-------------+
# only showing top 3 rows

# %%
df.take(10)
# Out:
# [Row(id=1, name='Advik Halder', full_name='Janya Bala', address='H.No. 916, Chokshi Road, Mumbai, Himachal Pradesh, 383408', json_string='{"city": "Bengaluru", "zipcode": "724094", "is_capital": false}', dob_string_format='1974-10-29', score=74, department='Sales', salary=95186, hobbies_list=['Photography'], user_id=2, txn_date=datetime.datetime(2025, 11, 29, 13, 20, 36, 61574), txn_value=132.71083639903748, street='20/662\nDua Nagar', city='Coimbatore', state='Rajasthan'),
#  Row(id=2, name='Omaja Baria', full_name='Manya Bhakta', address='492, Dass Road, Bengaluru, Mizoram, 103082', json_string='{"city": "Coimbatore", "zipcode": "494894", "is_capital": true}', dob_string_format='1978-04-26', score=33, department='Finance', salary=54210, hobbies_list=['Gaming', 'Cooking', 'Photography', 'Reading'], user_id=3, txn_date=datetime.datetime(2025, 11, 28, 13, 20, 36, 61679), txn_value=829.31653998402, street='H.No. 913, Chander Path', city='Bengaluru', state='Uttar Pradesh'),
#  Row(id=3, name='Unni Iyengar', full_name='Timothy Chaudry', address='H.No. 511\nJain Ganj, Coimbatore, Jharkhand, 040655', json_string='{"city": "Mumbai", "zipcode": "334596", "is_capital": false}', dob_string_format='1999-07-25', score=47, department='HR', salary=113058, hobbies_list=['Coding'], user_id=4, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 61785), txn_value=913.7253175783072, street='922, Krishnan Circle', city='Coimbatore', state='Uttar Pradesh'),
#  Row(id=4, name='Manthan Kulkarni', full_name='Thomas Ramakrishnan', address='47\nMammen, Coimbatore, Bihar, 152655', json_string='{"city": "Salem", "zipcode": "041029", "is_capital": true}', dob_string_format='1981-08-02', score=70, department='Engineering', salary=149570, hobbies_list=['Gaming', 'Music', 'Reading'], user_id=5, txn_date=datetime.datetime(2025, 11, 29, 13, 20, 36, 61881), txn_value=566.9216358462841, street='48/18\nBir Zila', city='Mumbai', state='Nagaland'),
#  Row(id=5, name='Ayaan Rege', full_name='Hiral Rajagopalan', address='95/81\nApte Marg, Mumbai, Meghalaya, 752051', json_string='{"city": "Coimbatore", "zipcode": "393996", "is_capital": true}', dob_string_format='1962-07-13', score=80, department='Engineering', salary=78937, hobbies_list=['Music'], user_id=6, txn_date=datetime.datetime(2025, 12, 4, 13, 20, 36, 61961), txn_value=271.9908394269114, street='21\nLanka Ganj', city='Coimbatore', state='Mizoram'),
#  Row(id=6, name='Aarush Sanghvi', full_name='Nitara Misra', address='05\nBawa Street, Chennai, Nagaland, 005744', json_string='{"city": "Mumbai", "zipcode": "995656", "is_capital": false}', dob_string_format='1975-05-04', score=71, department='Sales', salary=145117, hobbies_list=['Sports', 'Farming', 'Gaming'], user_id=7, txn_date=datetime.datetime(2025, 12, 15, 13, 20, 36, 62037), txn_value=500.23970115839415, street='H.No. 79\nSachar Path', city='Mumbai', state='Himachal Pradesh'),
#  Row(id=7, name='Tristan Sahota', full_name='Abdul Agate', address='H.No. 349\nNori Marg, Mumbai, Bihar, 678621', json_string='{"city": "Bengaluru", "zipcode": "607197", "is_capital": false}', dob_string_format='1989-01-22', score=33, department='Sales', salary=34016, hobbies_list=['Photography', 'Sports', 'Farming'], user_id=8, txn_date=datetime.datetime(2025, 11, 25, 13, 20, 36, 62109), txn_value=540.363762364439, street='58\nMall Circle', city='Salem', state='Assam'),
#  Row(id=8, name='Ikshita Radhakrishnan', full_name='Mason Dugar', address='H.No. 54\nPai Chowk, Coimbatore, Manipur, 808613', json_string='{"city": "Mumbai", "zipcode": "512139", "is_capital": true}', dob_string_format='1964-05-01', score=63, department='Finance', salary=136837, hobbies_list=['Photography', 'Music'], user_id=9, txn_date=datetime.datetime(2025, 12, 19, 13, 20, 36, 62187), txn_value=814.9417332484913, street='H.No. 76\nBawa', city='Mumbai', state='Uttarakhand'),
#  Row(id=9, name='Upadhriti Tata', full_name='Upadhriti Prabhakar', address='60/534, Swamy Path, Bengaluru, Punjab, 621238', json_string='{"city": "Chennai", "zipcode": "122272", "is_capital": true}', dob_string_format='2007-11-06', score=90, department='Finance', salary=123045, hobbies_list=['Gaming', 'Cooking', 'Coding', 'Farming'], user_id=10, txn_date=datetime.datetime(2025, 12, 16, 13, 20, 36, 62261), txn_value=87.03625781156568, street='H.No. 939\nVig Ganj', city='Salem', state='Arunachal Pradesh'),
#  Row(id=10, name='Arya Sharma', full_name='Nitesh Mukhopadhyay', address='03\nDubey Ganj, Mumbai, Gujarat, 888836', json_string='{"city": "Chennai", "zipcode": "559663", "is_capital": false}', dob_string_format='1973-02-28', score=73, department='Engineering', salary=36329, hobbies_list=['Trekking', 'Cooking', 'Sports', 'Gaming'], user_id=11, txn_date=datetime.datetime(2025, 12, 18, 13, 20, 36, 62338), txn_value=72.5659838971842, street='42/20, Pandey Ganj', city='Mumbai', state='Jharkhand')]

# %%
df.limit(4).collect()
# Out:
# [Row(id=1, name='Advik Halder', full_name='Janya Bala', address='H.No. 916, Chokshi Road, Mumbai, Himachal Pradesh, 383408', json_string='{"city": "Bengaluru", "zipcode": "724094", "is_capital": false}', dob_string_format='1974-10-29', score=74, department='Sales', salary=95186, hobbies_list=['Photography'], user_id=2, txn_date=datetime.datetime(2025, 11, 29, 13, 20, 36, 61574), txn_value=132.71083639903748, street='20/662\nDua Nagar', city='Coimbatore', state='Rajasthan'),
#  Row(id=2, name='Omaja Baria', full_name='Manya Bhakta', address='492, Dass Road, Bengaluru, Mizoram, 103082', json_string='{"city": "Coimbatore", "zipcode": "494894", "is_capital": true}', dob_string_format='1978-04-26', score=33, department='Finance', salary=54210, hobbies_list=['Gaming', 'Cooking', 'Photography', 'Reading'], user_id=3, txn_date=datetime.datetime(2025, 11, 28, 13, 20, 36, 61679), txn_value=829.31653998402, street='H.No. 913, Chander Path', city='Bengaluru', state='Uttar Pradesh'),
#  Row(id=3, name='Unni Iyengar', full_name='Timothy Chaudry', address='H.No. 511\nJain Ganj, Coimbatore, Jharkhand, 040655', json_string='{"city": "Mumbai", "zipcode": "334596", "is_capital": false}', dob_string_format='1999-07-25', score=47, department='HR', salary=113058, hobbies_list=['Coding'], user_id=4, txn_date=datetime.datetime(2025, 12, 6, 13, 20, 36, 61785), txn_value=913.7253175783072, street='922, Krishnan Circle', city='Coimbatore', state='Uttar Pradesh'),
#  Row(id=4, name='Manthan Kulkarni', full_name='Thomas Ramakrishnan', address='47\nMammen, Coimbatore, Bihar, 152655', json_string='{"city": "Salem", "zipcode": "041029", "is_capital": true}', dob_string_format='1981-08-02', score=70, department='Engineering', salary=149570, hobbies_list=['Gaming', 'Music', 'Reading'], user_id=5, txn_date=datetime.datetime(2025, 11, 29, 13, 20, 36, 61881), txn_value=566.9216358462841, street='48/18\nBir Zila', city='Mumbai', state='Nagaland')]

# %% [markdown]
# ## 🔥 7. Avoid UDFs Whenever Possible
# ❌ Python UDF

# %%
from pyspark.sql.functions import udf

# %% [markdown]
# Why bad:
#
#     * Runs row by row
#
#     * Breaks optimization
#
#     * Slower execution
#
# ✅ Prefer built-in functions
#
# Spark functions are:
#
#     * JVM optimized
#
#     * Vectorized
#
#     * Catalyst-aware
#
# Alternative:
#
#     * pandas_udf (vectorized)
#
#     * Built-in functions (best)
#
# ## 🔥 8. Filter Early, Reduce Data Early (Golden Rule)
#
# ❌ Bad practice:

# %%
df.groupBy("city").count().filter(df.city == "Chennai").show()
# Out:
# +-------+-----+
# |   city|count|
# +-------+-----+
# |Chennai| 3974|
# +-------+-----+

# %% [markdown]
# ## ✅ Good practice:

# %%
df.filter(df.city == "Chennai").select("id","city").show(5)
# Out:
# +---+-------+
# | id|   city|
# +---+-------+
# | 12|Chennai|
# | 21|Chennai|
# | 31|Chennai|
# | 40|Chennai|
# | 43|Chennai|
# +---+-------+
# only showing top 5 rows

# %%
df.filter(df.city == "Chennai").groupBy("city").count().show()
# Out:
# +-------+-----+
# |   city|count|
# +-------+-----+
# |Chennai| 3974|
# +-------+-----+

# %% [markdown]
# Why?
#
#     * Less data shuffled
#
#     * Faster execution
#
#     * Less memory usage
#
# ## 🔥 9. File Format Matters More Than Code
# ❌ CSV
#
#     * No schema
#
#     * No compression
#
#     * Slow
#
# ✅ Parquet
#
#     * Columnar
#
#     * Compressed
#
#     * Faster reads
#
#     * Predicate pushdown

# %%
df.write.parquet("Emp_wtn.parquet")

# %% [markdown]
# ## 🔥 10. Understanding .explain() (Very Important)

# %%
df.explain()
# Out:
# == Physical Plan ==
# *(1) ColumnarToRow
# +- FileScan parquet [id#0L,name#1,full_name#2,address#3,json_string#4,dob_string_format#5,score#6L,department#7,salary#8L,hobbies_list#9,user_id#10L,txn_date#11,txn_value#12,street#13,city#14,state#15] Batched: true, DataFilters: [], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/home/bhuvaneshwaran/Desktop/Medium/parquetFiles/Employees.parquet], PartitionFilters: [], PushedFilters: [], ReadSchema: struct<id:bigint,name:string,full_name:string,address:string,json_string:string,dob_string_format...

# %% [markdown]
# What it shows:
#
#     * Logical plan
#
#     * Physical plan
#
#     * Shuffles
#
#     * Joins
#
#     * Filters
#
# Reading execution plans makes you a real Spark engineer.
#
# 🔥 11. Spark UI — Your Best Debug Tool
#
# When Spark is running:
#
# * Open http://localhost:4040
#
# * Check:
#
#     * Stages
#
#     * Tasks
#
#     * Shuffle read/write
#
#     * Execution time
# ### ❗ Common Beginner Mistakes

# %% [markdown]
# | Mistake             | Impact           |
# | ------------------- | ---------------- |
# | Using collect()     | Driver crash     |
# | Too many partitions | Overhead         |
# | Too few partitions  | Poor parallelism |
# | Using CSV           | Slow IO          |
# | Overusing UDFs      | Slow execution   |
# | Ignoring Spark UI   | Blind debugging  |
